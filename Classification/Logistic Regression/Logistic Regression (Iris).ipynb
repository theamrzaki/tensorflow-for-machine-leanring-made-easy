# %% [markdown]
# http://yangshun.win/2017/08/27/tensorflow-learn/TensorFlow03/

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import time
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
iris = load_iris()
iris_X, iris_y = iris.data[:-1,:], iris.target[:-1]
iris_y= pd.get_dummies(iris_y).values
trainX, testX, trainY, testY = train_test_split(iris_X, iris_y, test_size=0.33, random_state=42)

# %%
# numFeatures is the number of features in our input data.
# In the iris dataset, this number is '4'.
numFeatures = trainX.shape[1]
# numLabels is the number of classes our data points can be in.
# In the iris dataset, this number is '3'.
numLabels = trainY.shape[1]
# Placeholders
# 'None' means TensorFlow shouldn't expect a fixed number in that dimension
X = tf.placeholder(tf.float32, [None, numFeatures]) # Iris has 4 features, so X is a tensor to hold our data.
yGold = tf.placeholder(tf.float32, [None, numLabels]) # This will be our correct answers matrix for 3 classes.

# %%
W = tf.Variable(tf.zeros([4, 3]))  # 4-dimensional input and  3 classes
b = tf.Variable(tf.zeros([3])) # 3-dimensional output [0,0,1],[0,1,0],[1,0,0]

# %%
#Randomly sample from a normal distribution with standard deviation .01
weights = tf.Variable(tf.random_normal([numFeatures,numLabels],
                                       mean=0,
                                       stddev=0.01,
                                       name="weights"))
bias = tf.Variable(tf.random_normal([1,numLabels],
                                    mean=0,
                                    stddev=0.01,
                                    name="bias"))

# %%
# Three-component breakdown of the Logistic Regression equation.
# Note that these feed into each other.
apply_weights_OP = tf.matmul(X, weights, name="apply_weights")
add_bias_OP = tf.add(apply_weights_OP, bias, name="add_bias") 
activation_OP = tf.nn.sigmoid(add_bias_OP, name="activation")

# %%
# Number of Epochs in our training
numEpochs = 700
# Defining our learning rate iterations (decay)
learningRate = tf.train.exponential_decay(learning_rate=0.0008,
                                          global_step= 1,
                                          decay_steps=trainX.shape[0],
                                          decay_rate= 0.95,
                                          staircase=True)

# %%
#Defining our cost function - Squared Mean Error
cost_OP = tf.nn.l2_loss(activation_OP-yGold, name="squared_error_cost")
#Defining our Gradient Descent
training_OP = tf.train.GradientDescentOptimizer(learningRate).minimize(cost_OP)

# %%
# Create a tensorflow session
sess = tf.Session()
# Initialize our weights and biases variables.
init_OP = tf.global_variables_initializer()
# Initialize all tensorflow variables
sess.run(init_OP)

# %%
# argmax(activation_OP, 1) returns the label with the most probability
# argmax(yGold, 1) is the correct label
correct_predictions_OP = tf.equal(tf.argmax(activation_OP,1),tf.argmax(yGold,1))
# If every false prediction is 0 and every true prediction is 1, the average returns us the accuracy
accuracy_OP = tf.reduce_mean(tf.cast(correct_predictions_OP, "float"))
# Summary op for regression output
activation_summary_OP = tf.summary.histogram("output", activation_OP)
# Summary op for accuracy
accuracy_summary_OP = tf.summary.scalar("accuracy", accuracy_OP)
# Summary op for cost
cost_summary_OP = tf.summary.scalar("cost", cost_OP)
# Summary ops to check how variables (W, b) are updating after each iteration
weightSummary = tf.summary.histogram("weights", weights.eval(session=sess))
biasSummary = tf.summary.histogram("biases", bias.eval(session=sess))
# Merge all summaries
merged = tf.summary.merge([activation_summary_OP, accuracy_summary_OP, cost_summary_OP, weightSummary, biasSummary])
# Summary writer
writer = tf.summary.FileWriter("summary_logs", sess.graph)

# %%
# Initialize reporting variables
cost = 0
diff = 1
epoch_values = []
accuracy_values = []
cost_values = []
# Training epochs
for i in range(numEpochs):
    if i > 1 and diff < .0001:
        print("change in cost %g; convergence."%diff)
        break
    else:
        # Run training step
        step = sess.run(training_OP, feed_dict={X: trainX, yGold: trainY})
        # Report occasional stats
        if i % 10 == 0:
            # Add epoch to epoch_values
            epoch_values.append(i)
            # Generate accuracy stats on test data
            train_accuracy, newCost = sess.run([accuracy_OP, cost_OP], feed_dict={X: trainX, yGold: trainY})
            # Add accuracy to live graphing variable
            accuracy_values.append(train_accuracy)
            # Add cost to live graphing variable
            cost_values.append(newCost)
            # Re-assign values for variables
            diff = abs(newCost - cost)
            cost = newCost
            #generate print statements
            print("step %d, training accuracy %g, cost %g, change in cost %g"%(i, train_accuracy, newCost, diff))
# How well do we perform on held-out test data?
print("final accuracy on test set: %s" %str(sess.run(accuracy_OP, 
                                                     feed_dict={X: testX, 
                                                                yGold: testY})))
# Out:
# step 0, training accuracy 0.333333, cost 34.8099, change in cost 34.8099
# step 10, training accuracy 0.535354, cost 30.2831, change in cost 4.5268
# step 20, training accuracy 0.646465, cost 28.308, change in cost 1.9751
# step 30, training accuracy 0.646465, cost 26.6425, change in cost 1.66542
# step 40, training accuracy 0.646465, cost 25.2598, change in cost 1.3827
# step 50, training accuracy 0.646465, cost 24.1184, change in cost 1.14147
# step 60, training accuracy 0.646465, cost 23.1742, change in cost 0.944168
# step 70, training accuracy 0.646465, cost 22.3882, change in cost 0.786055
# step 80, training accuracy 0.646465, cost 21.7279, change in cost 0.660248
# step 90, training accuracy 0.646465, cost 21.1678, change in cost 0.560104
# step 100, training accuracy 0.656566, cost 20.6878, change in cost 0.480003
# step 110, training accuracy 0.666667, cost 20.2723, change in cost 0.415464
# step 120, training accuracy 0.666667, cost 19.9093, change in cost 0.363039
# step 130, training accuracy 0.666667, cost 19.5892, change in cost 0.320078
# step 140, training accuracy 0.666667, cost 19.3047, change in cost 0.284557
# step 150, training accuracy 0.666667, cost 19.0497, change in cost 0.254944
# step 160, training accuracy 0.666667, cost 18.8197, change in cost 0.230042
# step 170, training accuracy 0.686869, cost 18.6107, change in cost 0.208942
# step 180, training accuracy 0.686869, cost 18.4198, change in cost 0.190931
# step 190, training accuracy 0.686869, cost 18.2444, change in cost 0.175438
# step 200, training accuracy 0.717172, cost 18.0823, change in cost 0.162035
# step 210, training accuracy 0.717172, cost 17.932, change in cost 0.15036
# step 220, training accuracy 0.737374, cost 17.7918, change in cost 0.140133
# step 230, training accuracy 0.737374, cost 17.6607, change in cost 0.131119
# step 240, training accuracy 0.747475, cost 17.5376, change in cost 0.123137
# step 250, training accuracy 0.757576, cost 17.4215, change in cost 0.116032
# step 260, training accuracy 0.767677, cost 17.3119, change in cost 0.109678
# step 270, training accuracy 0.787879, cost 17.2079, change in cost 0.10397
# step 280, training accuracy 0.787879, cost 17.1091, change in cost 0.0988216
# step 290, training accuracy 0.79798, cost 17.0149, change in cost 0.0941563
# step 300, training accuracy 0.79798, cost 16.925, change in cost 0.0899162
# step 310, training accuracy 0.79798, cost 16.839, change in cost 0.08605
# step 320, training accuracy 0.79798, cost 16.7564, change in cost 0.0825062
# step 330, training accuracy 0.79798, cost 16.6772, change in cost 0.0792503
# step 340, training accuracy 0.808081, cost 16.6009, change in cost 0.0762558
# step 350, training accuracy 0.818182, cost 16.5275, change in cost 0.0734844
# step 360, training accuracy 0.818182, cost 16.4565, change in cost 0.0709133
# step 370, training accuracy 0.818182, cost 16.388, change in cost 0.0685329
# step 380, training accuracy 0.838384, cost 16.3217, change in cost 0.0663071
# step 390, training accuracy 0.848485, cost 16.2575, change in cost 0.0642338
# step 400, training accuracy 0.848485, cost 16.1952, change in cost 0.0622921
# step 410, training accuracy 0.848485, cost 16.1347, change in cost 0.0604668
# step 420, training accuracy 0.848485, cost 16.076, change in cost 0.0587578
# step 430, training accuracy 0.848485, cost 16.0188, change in cost 0.0571442
# step 440, training accuracy 0.858586, cost 15.9632, change in cost 0.0556221
# step 450, training accuracy 0.868687, cost 15.909, change in cost 0.054184
# step 460, training accuracy 0.868687, cost 15.8562, change in cost 0.0528202
# step 470, training accuracy 0.868687, cost 15.8047, change in cost 0.0515289
# step 480, training accuracy 0.878788, cost 15.7544, change in cost 0.0503016
# step 490, training accuracy 0.878788, cost 15.7052, change in cost 0.0491333
# step 500, training accuracy 0.878788, cost 15.6572, change in cost 0.0480213
# step 510, training accuracy 0.878788, cost 15.6102, change in cost 0.046958
# step 520, training accuracy 0.878788, cost 15.5643, change in cost 0.0459442
# step 530, training accuracy 0.878788, cost 15.5193, change in cost 0.0449734
# step 540, training accuracy 0.888889, cost 15.4753, change in cost 0.0440445
# step 550, training accuracy 0.89899, cost 15.4321, change in cost 0.0431547
# step 560, training accuracy 0.89899, cost 15.3898, change in cost 0.0422983
# step 570, training accuracy 0.89899, cost 15.3483, change in cost 0.0414772
# step 580, training accuracy 0.89899, cost 15.3077, change in cost 0.0406866
# step 590, training accuracy 0.909091, cost 15.2677, change in cost 0.0399265
# step 600, training accuracy 0.909091, cost 15.2285, change in cost 0.0391932
# step 610, training accuracy 0.909091, cost 15.1901, change in cost 0.0384865
# step 620, training accuracy 0.909091, cost 15.1522, change in cost 0.0378046
# step 630, training accuracy 0.909091, cost 15.1151, change in cost 0.0371437
# step 640, training accuracy 0.909091, cost 15.0786, change in cost 0.0365076
# step 650, training accuracy 0.909091, cost 15.0427, change in cost 0.0358925
# step 660, training accuracy 0.909091, cost 15.0074, change in cost 0.0352945
# step 670, training accuracy 0.909091, cost 14.9727, change in cost 0.0347185
# step 680, training accuracy 0.909091, cost 14.9385, change in cost 0.0341578
# step 690, training accuracy 0.909091, cost 14.9049, change in cost 0.0336123
# final accuracy on test set: 0.9

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.plot([np.mean(cost_values[i-50:i]) for i in range(len(cost_values))])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
